# %%
"""
Preamble for most code and jupyter notebooks
@author: tobinsouth
@notebook date: 26 May 2021
"""

import numpy as np, pandas as pd

import matplotlib.pyplot as plt, seaborn as sns
import matplotlib as mpl

import math, string, re, pickle, json, time, os, sys, datetime, itertools

from collections import Counter
from tqdm import tqdm

# Set panda's options
pd.set_option("display.max_rows", 40)
pd.set_option("display.max_columns", 120)

# Better graphics
# %config InlineBackend.figure_formats = ['retina']
params = {
    'axes.labelsize': 10,
    'font.size': 10,
    'legend.fontsize': 8,
    'xtick.labelsize': 8,
    'ytick.labelsize': 8,
    'figure.figsize': [5.3, 3.34], # Thesis width
    'figure.dpi' : 72, 
    'font.family': "serif",
    'text.usetex': False, # Use LaTeX when desired
    }
plt.rcParams.update(params)

# Set packages to autoreload
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Get all loaded in data

# %%
import os
all_reports = []
for file in os.listdir("data"):
    if file[-6:] == 'pickle':
        if file[:16] == 'list_of_reports_':
            with open('data/'+file, 'rb') as f:
                all_reports.extend(pickle.load(f))
                
# # Remove other devices links
for r in all_reports:
    r.pop('other medical devices reported as being used', None)

# %%
all_reports_df = pd.DataFrame(all_reports)
len(all_reports_df.drop_duplicates())/ len(all_reports_df)
all_reports_df = all_reports_df.drop_duplicates()

# %%
len(all_reports_df)
# Out:
# 15264

# %% [markdown]
# # Comparing Word Usage

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer('[a-z]+') # Checks that word has a valid start, also returns start

word_usage_by_provider = all_reports_df.groupby('Report source category').apply(lambda df: " ".join(df['Event description'])).str.lower().apply(tokenizer.tokenize)

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words=set(stopwords.words('english')))
X = vectorizer.fit_transform(word_usage_by_provider.apply(" ".join))

word_usage = pd.DataFrame(X.toarray().T, index = vectorizer.get_feature_names(), columns = list(word_usage_by_provider.index))

top_words = []
for col in word_usage.columns:
    top_words.append(list(word_usage[col].sort_values(ascending=False)[:10].index))
top_words = pd.DataFrame(top_words, index = word_usage.columns).T
top_words
# Out:
#        Consumer Government Health Professional   Industry Medical Scientist  \
# 0          pain    wording             patient    patient          reactive
# 1          mesh     gloves              device   reported            slides
# 2       vaginal   required                line     device           suction
# 3  incontinence        nzs               blood        due          positive
# 4       patient       news             removed   revision         hepatitis
# 5          back       none            patients  procedure              core
# 6       bladder     choice            catheter   customer            result
# 7        pelvic        pro                 one       lead             false
# 8      constant    marking                used    surgery             mucin
# 9       erosion    sterile               noted  underwent               hbc
#
#      Other
# 0  patient
# 1    blood
# 2     line
# 3     leak
# 4   device
# 5  machine
# 6  leaking
# 7    found
# 8      bag
# 9     pump

# %% [markdown]
# ### Getting Activity Words

# %%
def expand_text_style(text):
    tokens = text.split('/')
    tokens = [t.replace('(s)','') for t in tokens]
    tokens = [t.split(',')[0].rstrip().lstrip() for t in tokens]
    return tokens + list(itertools.chain.from_iterable([t.split(' ') for t in tokens]))

# %% [markdown]
# [ 2011 Adult Compendium of Physical Activities](https://sites.google.com/site/compendiumofphysicalactivities/home)

# %%
CPA_activities = pd.read_csv('vocabulary/CPA_activities.csv')
all_activities = list(itertools.chain.from_iterable(CPA_activities['SPECIFIC ACTIVITIES'].str.split(',')))
all_activities.extend(CPA_activities['MAJOR HEADING'].to_list())
all_activities = list(set([a.rstrip().lstrip().lower() for a in all_activities if type(a) is str]))

# %%
# Text splitting
all_activities = list(set(itertools.chain.from_iterable([expand_text_style(text) for text in all_activities])))
all_activities.remove('')

# %%
# Manual Adding
activites = ['intercourse',  'overactive'] + ['experienced post', 'removed meshes', 'sexual intercourse']
all_activities = all_activities+activites

# %% [markdown]
# ### Getting medical probelm terms

# %% [markdown]
# Attached also a list with terminology of possible adverse events as classified by [IMDRF](http://imdrf.org/documents/documents.asp)

# %%
medical_problems = []
for file in os.listdir('vocabulary'):
    if (file[:5] == 'annex') and (file[-5:] == '.json'):
        with open('vocabulary/'+file, "r") as f:
            annex = json.load(f)
            medical_problems.extend(annex)
medical_problem_terms = [p['term'].lower() for p in medical_problems]
medical_problem_terms = list(set(medical_problem_terms))

# %%
medical_problem_terms = list(itertools.chain.from_iterable([expand_text_style(text) for text in medical_problem_terms]))
medical_problem_terms = list(set(medical_problem_terms)) # Remove duplicates

# %%
problems = ['dehiscence', 'discoloration', 'hernia', 'pain', 'incontinence', 'prolapse', 'pelvic prolapse', 'complications', 'infection', 'infections', 'painful', 'seroma', 'cystocele', 'dyspareunia', 'inflammation', 'discomfort', 'stress', 'complications', 'inflammation', 'recurrence'] + \
['mesh erosion', 'pain severe', 'severe scarring', 'scarring', 'bladder syndrome', 'overactive bladder', 'incisional hernia', 'hernia recurrence', 'constant pain', 'abdominal pain', 'pain intercourse', 'nerve pain', 'stress incontinence', 'umbilical hernia', 'tract infections', 'leg pain', 'painful sex', 'urinary incontinence', 'incontinence pain', 'cystocele recurrence', 'ongoing pain', 'ability walk', 'extreme pain', 'unable sex'] 

print(len([p for p in problems if p not in medical_problem_terms])/len(problems))
print([p for p in problems if p not in medical_problem_terms])
# [p for p in problems if p in medical_problem_terms]

medical_problem_terms = medical_problem_terms + problems
# Out:
# 0.5909090909090909
# ['pelvic prolapse', 'painful', 'cystocele', 'recurrence', 'mesh erosion', 'pain severe', 'severe scarring', 'scarring', 'bladder syndrome', 'overactive bladder', 'incisional hernia', 'hernia recurrence', 'constant pain', 'pain intercourse', 'nerve pain', 'stress incontinence', 'umbilical hernia', 'tract infections', 'leg pain', 'painful sex', 'incontinence pain', 'cystocele recurrence', 'ongoing pain', 'ability walk', 'extreme pain', 'unable sex']

# %%
for w in stopwords.words('english'):
    if w in medical_problem_terms: medical_problem_terms.remove(w)
    if w in all_activities: all_activities.remove(w)

# %% [markdown]
# # Look for activities and problems

# %%
insulin_df = all_reports_df[all_reports_df['GMDN term'].str.lower().apply(lambda s:'insulin' in s)]

# %%
report_word_map = {}
for i, report_text in enumerate(tqdm(insulin_df['Event description'])):
    found_activities = [a for a in all_activities if a in report_text]
    found_probelms = [p for p in medical_problem_terms if p in report_text]
    report_word_map[i] = {'act':found_activities, 'medprob':found_probelms}
# Out:
# 100%|██████████| 158/158 [00:00<00:00, 1103.09it/s]

# %%
# https://www.nltk.org/_modules/nltk/metrics/association.html
# https://www.nltk.org/howto/collocations.html

import nltk
bigram_measures = nltk.collocations.BigramAssocMeasures() # Use for computing scores

all_singles = list(itertools.chain.from_iterable([r['act']+r['medprob'] for r in report_word_map.values()]))
all_pairs = list(itertools.chain.from_iterable([ [(act, prob) for act in r['act'] for prob in r['medprob']] for r in report_word_map.values()]))

single_frequencies = nltk.FreqDist(all_singles)
pair_frequencies = nltk.FreqDist(all_pairs)
finder = nltk.collocations.BigramCollocationFinder(single_frequencies, pair_frequencies)
scores = finder.score_ngrams(bigram_measures.student_t) # likelihood_ratio

# %%
removal = ['h','ic', 'patient', 'th', '-']
[s for s in scores if (s[0][0] not in removal) and (s[0][1] not in removal) and (s[0][0]!=s[0][1])]
# Out:
# [(('deliver', 'liver'), 5.494173473689984),
#  (('high', 'due'), 4.44405048759028),
#  (('deliver', 'pump'), 4.180940676063974),
#  (('2', 'pump'), 4.174166797051436),
#  (('ring', 'pump'), 4.060582528552559),
#  (('ring', 'liver'), 4.025732986049425),
#  (('deliver', 'ring'), 3.8219712062565265),
#  (('ring', 'deliver'), 3.8219712062565265),
#  (('ton', 'pump'), 3.709626140145161),
#  (('2', 'red'), 3.6275327605978296),
#  (('level', 'blood'), 3.5511689032850455),
#  (('deliver', 'delivered'), 3.5050043117909198),
#  (('deliver', 'red'), 3.480801098371401),
#  (('0', 'pump'), 3.477933975417401),
#  (('level', 'pump'), 3.4619818129115774),
#  (('one', 'pump'), 3.4540057316586656),
#  (('high', 'blood'), 3.369894329355232),
#  (('arm', 'alarm'), 3.2949475041439267),
#  (('high', 'pump'), 3.293807797441236),
#  (('1', 'pump'), 3.2731609378763493),
#  (('2', 'port'), 3.2283391156032177),
#  (('2', 'time'), 3.184196278227127),
#  (('low', 'pump'), 3.1486344092276064),
#  (('high', 'liver'), 3.1403326406510237),
#  (('ton', 'button'), 3.1319638873911657),
#  (('delivering', 'liver'), 3.1168070010025595),
#  (('delivering', 'deliver'), 3.0740921393619405),
#  (('delivering', 'ring'), 3.0740921393619405),
#  (('delivery', 'liver'), 3.0713363418367394),
#  (('2', 'blood'), 3.065824746786337),
#  (('4', 'pump'), 3.0076774190045916),
#  (('time', 'pump'), 3.0044718689101857),
#  (('time', 'red'), 2.9886624160807034),
#  (('deliver', 'delivery'), 2.985906618555502),
#  (('delivery', 'deliver'), 2.985906618555502),
#  (('ring', 'port'), 2.950632410232927),
#  (('one', 'blood'), 2.9310094408133622),
#  (('min', 'red'), 2.9288307915758893),
#  (('ton', 'blood'), 2.9201161946259986),
#  (('2', 'ring'), 2.9153582019103514),
#  (('delivering', 'pump'), 2.904139433551198),
#  (('set', 'red'), 2.893246187363834),
#  (('2', 'liver'), 2.8657952069716774),
#  (('deliver', 'high'), 2.836186028254397),
#  (('high', 'deliver'), 2.836186028254397),
#  (('cha', 'change'), 2.8037785223518874),
#  (('hang', 'change'), 2.8037785223518874),
#  (('deliver', 'blood'), 2.767610748002905),
#  (('5', 'time'), 2.7563299627428557),
#  (('0', 'red'), 2.7421570163661317),
#  (('2', 'deliver'), 2.7397240377632532),
#  (('20', 'pump'), 2.7369191883573425),
#  (('level', 'liver'), 2.7369191883573425),
#  (('2', 'use'), 2.733530005528126),
#  (('time', 'use'), 2.706416542894394),
#  (('1', 'red'), 2.7044138439498564),
#  (('5', 'pump'), 2.696248994406744),
#  (('8', 'pump'), 2.696248994406744),
#  (('min', 'pump'), 2.686081445919094),
#  (('ring', 'red'), 2.6746550472040664),
#  (('7', 'ring'), 2.6706760694226555),
#  (('7', 'pump'), 2.6657463489437947),
#  (('level', 'deliver'), 2.6509571875072133),
#  (('set', 'pump'), 2.6149086065055465),
#  (('set', 'infusion'), 2.614624825052066),
#  (('new', 'pump'), 2.6047410580178965),
#  (('low', 'follow'), 2.601943664084),
#  (('one', 'use'), 2.5769107229522348),
#  (('low', 'battery'), 2.5643942523863514),
#  (('1', 'port'), 2.554842209059757),
#  (('7', 'red'), 2.5535246858422953),
#  (('1', 'blood'), 2.5510543298095554),
#  (('level', 'red'), 2.5419963576895084),
#  (('6', 'pump'), 2.5261860790799724),
#  (('ton', 'red'), 2.5189397013839345),
#  (('time', 'blood'), 2.4975299491001874),
#  (('2', 'low'), 2.4705207231422297),
#  (('level', 'ring'), 2.456027967750155),
#  (('play', 'display'), 2.443085848030804),
#  (('multiple', 'tip'), 2.4324126901101804),
#  (('1', 'unit'), 2.416758725159932),
#  (('deliver', 'use'), 2.4138672247913915),
#  (('ring', 'use'), 2.4138672247913915),
#  (('set', 'remove'), 2.4083980847887765),
#  (('5', 'use'), 2.398614356694871),
#  (('20', 'red'), 2.393455663699903),
#  (('set', 'ear'), 2.393455663699903),
#  (('5', 'blood'), 2.3916768040464658),
#  (('2', 'delivered'), 2.3847392513980603),
#  (('ring', 'blood'), 2.3822466675723186),
#  (('0', 'blood'), 2.378335356645686),
#  (('go', 'pump'), 2.3673064267943746),
#  (('place', 'pump'), 2.3673064267943746),
#  (('time', 'delivered'), 2.366239111002312),
#  (('ton', 'use'), 2.363392935556812),
#  (('ton', 'high'), 2.363142580919129),
#  (('min', 'time'), 2.359835216249938),
#  (('0', 'liver'), 2.355565953081688),
#  (('7', 'liver'), 2.355565953081688),
#  (('days', 'pump'), 2.355565953081688),
#  (('4', 'red'), 2.343647593403658),
#  (('2', 'new'), 2.3399119881314396),
#  (('new', 'red'), 2.312517549468505),
#  (('delivering', 'high'), 2.310738689815068),
#  (('ring', 'delivered'), 2.301488619617194),
#  (('high', 'ring'), 2.2749455337690634),
#  (('ring', 'high'), 2.2749455337690634),
#  (('arm', 'pump'), 2.2733826370928845),
#  (('0', 'deliver'), 2.2673345142711976),
#  (('0', 'ring'), 2.2673345142711976),
#  (('7', 'deliver'), 2.2673345142711976),
#  (('low', 'ring'), 2.2452242529563375),
#  (('ring', 'low'), 2.2452242529563375),
#  (('time', 'liver'), 2.238161215954826),
#  (('reading', 'read'), 2.2272990834703785),
#  (('sit', 'site'), 2.2263247619115556),
#  (('work', 'working'), 2.2263247619115556),
#  (('delivery', 'pump'), 2.2146802685294533),
#  (('min', 'unit'), 2.2142431745821445),
#  (('low', 'red'), 2.2129014088760157),
#  (('2', 'contact'), 2.203330773123322),
#  (('4', 'issue'), 2.2029410444997928),
#  (('mini', 'red'), 2.2019667229409694),
#  (('days', 'use'), 2.2017718586292045),
#  (('2', 'follow'), 2.197874572393911),
#  (('back', 'red'), 2.1951464720292053),
#  (('set', 'issue'), 2.1951464720292053),
#  (('20', 'blood'), 2.192223507352735),
#  (('0', 'ear'), 2.1893005426762646),
#  (('1', 'ring'), 2.187641601797206),
#  (('set', 'led'), 2.1869621709350886),
#  (('one', 'high'), 2.1858627421437684),
#  (('2', 'issue'), 2.181505970205677),
#  (('2', 'rate'), 2.181505970205677),
#  (('20', 'liver'), 2.1781932769056773),
#  (('min', 'use'), 2.1760497694762657),
#  (('5', 'port'), 2.1752703122292067),
#  (('ring', 'syringe'), 2.1737113977350897),
#  (('arm', 'use'), 2.1717627546174425),
#  (('lock', 'pump'), 2.1717627546174425),
#  (('reading', 'pump'), 2.1717627546174425),
#  (('work', 'pump'), 2.1717627546174425),
#  (('2', 'led'), 2.1705935687468543),
#  (('sit', 'red'), 2.167865468382149),
#  (('7', 'port'), 2.1612400817821493),
#  (('6', 'red'), 2.161045217470385),
#  (('6', 'time'), 2.1589017100409733),
#  (('play', 'pump'), 2.1589017100409733),
#  (('level', 'port'), 2.1518865948174444),
#  (('5', 'red'), 2.1474047156468568),
#  (('8', 'red'), 2.1474047156468568),
#  (('low', 'led'), 2.147209851335092),
#  (('delivery', 'blood'), 2.138635821617446),
#  (('set', 'port'), 2.137856364370387),
#  (('arm', 'due'), 2.1366871784997987),
#  (('deliver', 'unit'), 2.1362974498762695),
#  (('new', 'port'), 2.1331796208880345),
#  (('ton', 'port'), 2.1331796208880345),
#  (('2', 'delivery'), 2.1269439629115645),
#  (('0', 'time'), 2.1238261339233295),
#  (('20', 'deliver'), 2.1238261339233295),
#  (('ring', 'ugh'), 2.1238261339233295),
#  (('4', 'time'), 2.116811018699801),
#  (('deliver', 'rate'), 2.1113548179703896),
#  (('hang', 'pump'), 2.1074575317350956),
#  (('working', 'pump'), 2.1074575317350956),
#  (('one', 'red'), 2.1064832101762727),
#  (('one', 'time'), 2.102780788252743),
#  (('one', 'low'), 2.095375944405685),
#  (('1', 'liver'), 2.088165964870392),
#  (('deliver', 'led'), 2.0864121860645097),
#  (('5', 'ring'), 2.07394087011157),
#  (('time', 'port'), 2.0677052121350994),
#  (('1', 'low'), 2.0657565690174526),
#  (('deliver', 'due'), 2.0624098821952193),
#  (('min', 'ring'), 2.0614695541586294),
#  (('low', 'blood'), 2.0509468813233362),
#  (('arm', 'ring'), 2.0489982382056895),
#  (('deliver', 'time'), 2.0396404786312217),
#  (('ring', 'time'), 2.0396404786312217),
#  (('time', 'deliver'), 2.0396404786312217),
#  (('time', 'ring'), 2.0396404786312217),
#  (('5', 'high'), 2.0384755653703963),
#  (('arm', 'high'), 2.008076732735105),
#  (('high', 'error'), 2.008076732735105),
#  (('abdominal', 'abdominal pain'), 1.9965141612200437),
#  (('abdominal', 'pain'), 1.9965141612200437),
#  (('disco', 'disc'), 1.9965141612200437),
#  (('disco', 'disconnect'), 1.9965141612200437),
#  (('ping', 'pin'), 1.9965141612200437),
#  (('reading', 'readings'), 1.9956427015250544),
#  (('days', 'abdominal pain'), 1.993028322440087),
#  (('days', 'pain'), 1.993028322440087),
#  (('min', 'abdominal pain'), 1.9877995642701525),
#  (('min', 'pain'), 1.9877995642701525),
#  (('arm', 'abdominal pain'), 1.9869281045751634),
#  (('arm', 'pain'), 1.9869281045751634),
#  (('delivery', 'ring'), 1.9866416584409894),
#  (('ring', 'delivery'), 1.9866416584409894),
#  (('0', 'dose'), 1.9825708061002179),
#  (('days', 'led'), 1.9790849673202615),
#  (('6', 'infusion'), 1.9784313725490197),
#  (('sugar', 'blood'), 1.9782135076252723),
#  (('one', 'nausea'), 1.9751633986928105),
#  (('20', 'delivered'), 1.9745098039215687),
#  (('set', 'insert'), 1.9725490196078432),
#  (('chi', 'use'), 1.9712418300653596),
#  (('new', 'insert'), 1.9712418300653596),
#  (('ton', 'nausea'), 1.9712418300653596),
#  (('8', 'remove'), 1.9688453159041395),
#  (('min', 'alarm'), 1.9664488017429194),
#  (('high', 'red'), 1.963861057394792),
#  (('2', 'vomiting'), 1.9633986928104574),
#  (('level', 'high'), 1.9624784837821685),
#  (('new', 'ring'), 1.9616990265351095),
#  (('ring', 'new'), 1.9616990265351095),
#  (('level', 'rate'), 1.9607843137254901),
#  (('min', 'delivered'), 1.9603485838779957),
#  (('4', 'remove'), 1.9592592592592593),
#  (('8', 'ear'), 1.957516339869281),
#  (('2', 'end'), 1.9572984749455338),
#  (('20', 'use'), 1.9568627450980391),
#  (('delivery', 'rate'), 1.9564270152505447),
#  (('0', 'delivered'), 1.9546840958605665),
#  (('2', 'unit'), 1.9511982570806101),
#  (('1', 'deliver'), 1.9492277105821694),
#  (('level', 'delivered'), 1.9490196078431372),
#  (('7', 'ear'), 1.9477124183006536),
#  (('6', 'use'), 1.947276688453159),
#  (('ton', 'remove'), 1.947276688453159),
#  (('go', 'red'), 1.946623093681917),
#  (('2', 'infusion'), 1.9450980392156862),
#  (('2', 'ugh'), 1.9450980392156862),
#  (('4', 'ear'), 1.9444444444444444),
#  (('15', 'pump'), 1.942483660130719),
#  (('sugar', 'pump'), 1.942483660130719),
#  (('6', 'blood'), 1.9400871459694988),
#  (('days', 'red'), 1.9389978213507626),
#  (('time', 'unit'), 1.9372549019607843),
#  (('deliver', 'port'), 1.9367563946292294),
#  (('set', 'cannula'), 1.9359477124183007),
#  (('2', 'remove'), 1.9328976034858387),
#  (('20', 'time'), 1.9294117647058824),
#  (('cat', 'pump'), 1.9281045751633987),
#  (('ton', 'ear'), 1.9281045751633987),
#  (('set', 'using'), 1.926797385620915),
#  (('1', 'ear'), 1.9248366013071896),
#  (('min', 'blood'), 1.9237472766884531),
#  (('0', 'use'), 1.9233115468409585),
#  (('7', 'use'), 1.9233115468409585),
#  (('arm', 'port'), 1.9215686274509804),
#  (('time', 'rate'), 1.9215686274509804),
#  (('6', 'liver'), 1.9209150326797386),
#  (('4', 'use'), 1.9185185185185185),
#  (('hang', 'low'), 1.9172113289760349),
#  (('low', 'without'), 1.9172113289760349),
#  (('sit', 'low'), 1.9172113289760349),
#  (('without', 'low'), 1.9172113289760349),
#  (('ring', 'result'), 1.9163398692810458),
#  (('back', 'pump'), 1.9137254901960785),
#  (('chi', 'pump'), 1.9137254901960785),
#  (('7', 'blood'), 1.9128540305010893),
#  (('2', 'ear'), 1.908496732026144),
#  (('5', 'liver'), 1.9065359477124182),
#  (('delivery', 'use'), 1.9041394335511983),
#  (('ring', 'end'), 1.90239651416122),
#  (('ring', 'follow'), 1.90239651416122),
#  (('one', 'port'), 1.9006535947712417),
#  (('min', 'liver'), 1.899346405228758),
#  (('8', 'time'), 1.8980392156862744),
#  (('new', 'use'), 1.894553376906318),
#  (('arm', 'liver'), 1.892156862745098),
#  (('1', 'use'), 1.889760348583878),
#  (('ring', 'needle'), 1.8884531590413944),
#  (('ring', 'unit'), 1.8884531590413944),
#  (('arm', 'red'), 1.8856209150326797),
#  (('20', 'ring'), 1.8745098039215686),
#  (('7', 'time'), 1.8745098039215686),
#  (('deliver', 'ugh'), 1.8745098039215686),
#  (('high', 'port'), 1.8712819858762946),
#  (('9', 'pump'), 1.8705882352941177),
#  (('7', 'low'), 1.8675381263616557),
#  (('level', 'time'), 1.8588235294117648),
#  (('cha', 'pump'), 1.8562091503267975),
#  (('ice', 'pump'), 1.8562091503267975),
#  (('sit', 'pump'), 1.8562091503267975),
#  (('without', 'pump'), 1.8562091503267975),
#  (('level', 'low'), 1.8509803921568628),
#  (('delivery', 'red'), 1.8474945533769063),
#  (('6', 'deliver'), 1.8466230936819172),
#  (('6', 'ring'), 1.8466230936819172),
#  (('new', 'liver'), 1.8418300653594772),
#  (('ton', 'liver'), 1.8418300653594772),
#  (('ton', 'due'), 1.837037037037037),
#  (('ton', 'time'), 1.8274509803921568),
#  (('1', 'time'), 1.8196078431372549),
#  (('5', 'deliver'), 1.8187363834422658),
#  (('ton', 'low'), 1.8178649237472766),
#  (('high', 'alarm'), 1.8130718954248366),
#  (('min', 'deliver'), 1.80479302832244),
#  (('low', 'port'), 1.8013071895424837),
#  (('ring', 'ear'), 1.7908496732026145),
#  (('high', 'delivered'), 1.7790849673202613),
#  (('change', 'pump'), 1.7699346405228757),
#  (('one', 'ring'), 1.7350762527233115),
#  (('80', 'inflammation'), 1.7312961013346426),
#  (('firm', 'inflammation'), 1.7312961013346426),
#  (('upper', 'inflammation'), 1.7312961013346426),
#  (('–', 'inflammation'), 1.7312961013346426),
#  (('care', 'inflammation'), 1.7305413951004078),
#  (('different', 'inflammation'), 1.7305413951004078),
#  (('inside', 'inflammation'), 1.7305413951004078),
#  (('minute', 'nut'), 1.729786688866173),
#  (('ski', 'inflammation'), 1.729786688866173),
#  (('ski', 'skin'), 1.729786688866173),
#  (('sod', 'episode'), 1.729786688866173),
#  (('car', 'inflammation'), 1.7290319826319382),
#  (('lock', 'block'), 1.7282772763977035),
#  (('lock', 'blockage'), 1.7282772763977035),
#  (('tai', 'inflammation'), 1.7282772763977035),
#  (('tai', 'problems'), 1.7282772763977035),
#  (('work', 'not working'), 1.7282772763977035),
#  (('7', 'high'), 1.7281045751633988),
#  (('back', 'inflammation'), 1.7275225701634687),
#  (('lock', 'test'), 1.7270194326739787),
#  (('tai', 'problem'), 1.7270194326739787),
#  (('area', 'inflammation'), 1.726013157694999),
#  (('days', 'inflammation'), 1.726013157694999),
#  (('9', 'inflammation'), 1.725258451460764),
#  (('ice', 'inflammation'), 1.7245037452265293),
#  (('sit', 'inflammation'), 1.7245037452265293),
#  (('working', 'not working'), 1.7245037452265293),
#  (('11', 'unit'), 1.7240006077370393),
#  (('5', 'inflammation'), 1.722239626523825),
#  (('8', 'inflammation'), 1.722239626523825),
#  (('mini', 'unit'), 1.72198805777908),
#  (('min', 'inflammation'), 1.72148492028959),
#  (('min', 'nut'), 1.72148492028959),
#  (('years', 'ear'), 1.7207302140553553),
#  (('0', 'inflammation'), 1.7199755078211205),
#  (('7', 'inflammation'), 1.7199755078211205),
#  (('back', 'light'), 1.7199755078211205),
#  (('days', 'contact'), 1.7199755078211205),
#  (('days', 'vomiting'), 1.7199755078211205),
#  (('tai', 'rate'), 1.7194723703316306),
#  (('work', 'button'), 1.7194723703316306),
#  (('min', 'problem'), 1.717962957863161),
#  (('one', 'inflammation'), 1.7177113891184161),
#  (('lock', 'led'), 1.7169566828841814),
#  (('set', 'inflammation'), 1.7162019766499466),
#  (('0', 'problem'), 1.7159504079052015),
#  (('days', 'screen'), 1.7159504079052015),
#  (('1', 'nut'), 1.714692564181477),
#  (('go', 'issue'), 1.714440995436732),
#  (('go', 'without'), 1.714440995436732),
#  (('min', 'mount'), 1.714440995436732),
#  (('min', 'short'), 1.714440995436732),
#  (('ports', 'port'), 1.7139378579472422),
#  (('place', 'remove'), 1.7126800142235175),
#  (('5', 'nausea'), 1.7124284454787726),
#  (('8', 'insert'), 1.7124284454787726),
#  (('20', 'infusion'), 1.7116737392445378),
#  (('20', 'ugh'), 1.7116737392445378),
#  (('2', 'dent'), 1.710919033010303),
#  (('2', 'inflammation'), 1.710919033010303),
#  (('2', 'problems'), 1.710919033010303),
#  (('min', 'nausea'), 1.710919033010303),
#  (('6', 'unit'), 1.709912758031323),
#  (('child', 'use'), 1.709912758031323),
#  (('ton', 'unresponsive'), 1.709912758031323),
#  (('arm', 'vomiting'), 1.7094096205418334),
#  (('chi', 'ear'), 1.7094096205418334),
#  (('sit', 'infusion'), 1.7094096205418334),
#  (('one', 'side'), 1.7081517768181085),
#  (('7', 'contact'), 1.7079002080733636),
#  (('set', 'ring'), 1.70718954248366),
#  (('working', 'button'), 1.7068939330943838),
#  (('5', 'unit'), 1.705887658115404),
#  (('power', 'battery'), 1.705887658115404),
#  (('set', 'site'), 1.7056360893706592),
#  (('time', 'inflammation'), 1.7048813831364245),
#  (('ice', 'remove'), 1.7043782456469345),
#  (('2', 'problem'), 1.7038751081574446),
#  (('7', 'end'), 1.7038751081574446),
#  (('7', 'follow'), 1.7038751081574446),
#  (('low', 'inflammation'), 1.7033719706679549),
#  (('one', 'contact'), 1.7033719706679549),
#  (('one', 'vomiting'), 1.7033719706679549),
#  (('1', 'mount'), 1.7031204019232098),
#  (('1', 'short'), 1.7031204019232098),
#  (('delivery', 'event'), 1.7018625581994853),
#  (('event', 'delivery'), 1.7018625581994853),
#  (('0', 'unit'), 1.6998500082415258),
#  (('7', 'unit'), 1.6998500082415258),
#  (('without', 'battery'), 1.6993468707520358),
#  (('child', 'liver'), 1.6988437332625461),
#  (('event', 'use'), 1.6988437332625461),
#  (('new', 'contact'), 1.6988437332625461),
#  (('sugar', 'liver'), 1.6988437332625461),
#  (('ton', 'insert'), 1.6988437332625461),
#  (('ton', 'vomiting'), 1.6988437332625461),
#  (('4', 'tip'), 1.6978374582835662),
#  (('11', 'red'), 1.6968311833045866),
#  (('2', 'short'), 1.6968311833045866),
#  (('car', 'red'), 1.6968311833045866),
#  (('sit', 'cannula'), 1.6968311833045866),
#  (('sugar', 'red'), 1.6968311833045866),
#  (('6', 'delivered'), 1.6960764770703518),
#  (('0', 'infusion'), 1.695824908325607),
#  (('0', 'read'), 1.695824908325607),
#  (('0', 'ugh'), 1.695824908325607),
#  (('7', 'infusion'), 1.695824908325607),
#  (('level', 'unit'), 1.695824908325607),
#  (('set', 'end'), 1.6950702020913722),
#  (('back', 'blood'), 1.694315495857137),
#  (('sit', 'ear'), 1.694315495857137),
#  (('one', 'light'), 1.6938123583676474),
#  (('one', 'screen'), 1.6938123583676474),
#  (('one', 'unit'), 1.6938123583676474),
#  (('4', 'infusion'), 1.6935607896229021),
#  (('4', 'ugh'), 1.6935607896229021),
#  (('deliver', 'new'), 1.6932461873638345),
#  (('new', 'deliver'), 1.6932461873638345),
#  (('ton', 'deliver'), 1.6932461873638345),
#  (('ton', 'ring'), 1.6932461873638345),
#  (('8', 'led'), 1.6928060833886673),
#  (('0', 'button'), 1.6917998084096877),
#  (('1', 'follow'), 1.6915482396649428),
#  (('level', 'infusion'), 1.6912966709201978),
#  (('lock', 'liver'), 1.690541964685963),
#  (('2', 'event'), 1.6897872584517282),
#  (('2', 'nausea'), 1.6897872584517282),
#  (('2', 'result'), 1.6897872584517282),
#  (('set', 'needle'), 1.6897872584517282),
#  (('5', 'delivered'), 1.6895356897069833),
#  (('8', 'battery'), 1.6895356897069833),
#  (('one', 'infusion'), 1.6890325522174934),
#  (('go', 'blood'), 1.6880262772385137),
#  (('place', 'blood'), 1.6880262772385137),
#  (('tai', 'red'), 1.6880262772385137),
#  (('ton', 'light'), 1.6877747084937689),
#  (('ton', 'unit'), 1.6877747084937689),
#  (('tai', 'time'), 1.686768433514789),
#  (('cat', 'low'), 1.6842527460673398),
#  (('low', 'found'), 1.6842527460673398),
#  (('0', 'led'), 1.6837496085778498),
#  (('7', 'led'), 1.6837496085778498),
#  (('deliver', 'block'), 1.6837496085778498),
#  (('deliver', 'blockage'), 1.6837496085778498),
#  (('deliver', 'inaccurate'), 1.6837496085778498),
#  (('ring', 'form'), 1.6837496085778498),
#  (('ring', 'inflammation'), 1.6837496085778498),
#  (('using', 'led'), 1.6837496085778498),
#  (('5', 'ear'), 1.682994902343615),
#  (('chi', 'liver'), 1.6822401961093802),
#  (('event', 'liver'), 1.6822401961093802),
#  (('level', 'alarm'), 1.6822401961093802),
#  (('new', 'infusion'), 1.6822401961093802),
#  (('ton', 'infusion'), 1.6822401961093802),
#  (('years', 'pump'), 1.6822401961093802),
#  (('delivery', 'issue'), 1.6817370586198905),
#  (('light', 'blood'), 1.6817370586198905),
#  (('4', 'multiple'), 1.6807307836409107),
#  (('1', 'ugh'), 1.6799760774066759),
#  (('7', 'delivered'), 1.679724508661931),
#  (('one', 'remove'), 1.6794729399171862),
#  (('min', 'ear'), 1.679221371172441),
#  (('20', 'port'), 1.6777119587039713),
#  (('time', 'nausea'), 1.6777119587039713),
#  (('cha', 'new'), 1.6767056837249916),
#  (('hang', 'new'), 1.6767056837249916),
#  (('ton', 'working'), 1.6767056837249916),
#  (('arm', 'error'), 1.675447840001267),
#  (('chi', 'low'), 1.674693133767032),
#  (('low', 'contact'), 1.674693133767032),
#  (('low', 'result'), 1.674693133767032),
#  (('1', 'button'), 1.6741899962775424),
#  (('1', 'rate'), 1.6741899962775424),
#  (('cha', 'port'), 1.671674308830093),
#  (('hang', 'port'), 1.671674308830093),
#  (('new', 'remove'), 1.671171171340603),
#  (('place', 'red'), 1.6704164651063682),
#  (('delivering', 'blood'), 1.6691586213826437),
#  (('hang', 'blood'), 1.6691586213826437),
#  (('sit', 'blood'), 1.6691586213826437),
#  (('time', 'end'), 1.6686554838931538),
#  (('1', 'remove'), 1.668403915148409),
#  (('4', 'error'), 1.667900777658919),
#  (('0', 'using'), 1.6676492089141741),
#  (('child', 'deliver'), 1.6676492089141741),
#  (('child', 'ring'), 1.6676492089141741),
#  (('deliver', 'reservoir'), 1.6676492089141741),
#  (('deliver', 'test'), 1.6676492089141741),
#  (('ring', 'readings'), 1.6676492089141741),
#  (('ring', 'reservoir'), 1.6676492089141741),
#  (('sugar', 'deliver'), 1.6676492089141741),
#  (('delivery', 'delivered'), 1.6666429339351942),
#  (('11', 'pump'), 1.6656366589562146),
#  (('child', 'pump'), 1.6656366589562146),
#  (('days', 'liver'), 1.6656366589562146),
#  (('multiple', 'use'), 1.6656366589562146),
#  (('self', 'pump'), 1.6656366589562146),
#  (('go', 'low'), 1.6651335214667247),
#  (('low', 'end'), 1.6651335214667247),
#  (('level', 'ear'), 1.664127246487745),
#  (('2', 'button'), 1.6616115590402958),
#  (('2', 'without'), 1.6616115590402958),
#  (('light', 'red'), 1.6616115590402958),
#  (('one', 'ear'), 1.6603537153165708),
#  (('delivery', 'high'), 1.6601307189542482),
#  (('high', 'delivery'), 1.6601307189542482),
#  (('8', 'use'), 1.660102146571826),
#  (('new', 'battery'), 1.660102146571826),
#  (('ton', 'battery'), 1.660102146571826),
#  (('ton', 'delivered'), 1.660102146571826),
#  (('time', 'tip'), 1.659599009082336),
#  (('1', 'delivered'), 1.6568317528901417),
#  (('days', 'low'), 1.6555739091664172),
#  (('min', 'new'), 1.6545676341874374),
#  (('high', 'readings'), 1.6535613592084577),
#  (('high', 'unresponsive'), 1.6535613592084577),
#  (('9', 'red'), 1.652806652974223),
#  (('deliver', 'mount'), 1.6515488092504982),
#  (('lock', 'deliver'), 1.6515488092504982),
#  (('reading', 'ring'), 1.6515488092504982),
#  (('ring', 'mount'), 1.6515488092504982),
#  (('time', 'ugh'), 1.6505425342715185),
#  (('10', 'pump'), 1.649033121803049),
#  (('new', 'error'), 1.649033121803049),
#  (('tai', 'pump'), 1.649033121803049),
#  (('low', 'ugh'), 1.6460142968661098),
#  (('cha', 'red'), 1.64400174690815),
#  (('hang', 'red'), 1.64400174690815),
#  (('without', 'red'), 1.64400174690815),
#  (('ton', 'using'), 1.64349860941866),
#  (('level', 'delivery'), 1.6414860594607008),
#  (('1', 'change'), 1.6394735095027413),
#  (('1', 'using'), 1.6394735095027413),
#  (('cha', 'low'), 1.6364546845658021),
#  (('0', 'port'), 1.6354484095868225),
#  (('change', 'port'), 1.6354484095868225),
#  (('chi', 'deliver'), 1.6354484095868225),
#  (('chi', 'ring'), 1.6354484095868225),
#  (('deliver', 'cause'), 1.6354484095868225),
#  (('deliver', 'event'), 1.6354484095868225),
#  (('event', 'deliver'), 1.6354484095868225),
#  (('reading', 'high'), 1.6339389971183529),
#  (('event', 'pump'), 1.6324295846498833),
#  (('level', 'use'), 1.6324295846498833),
#  (('run', 'pump'), 1.6324295846498833),
#  (('low', 'remove'), 1.6268950722654945),
#  (('one', 'new'), 1.6268950722654945),
#  (('high', 'use'), 1.6261437908496732),
#  (('8', 'liver'), 1.6241278160733001),
#  (('multiple', 'time'), 1.6233731098390654),
#  (('time', 'multiple'), 1.6233731098390654),
#  (('delivery', 'new'), 1.621360559881106),
#  (('new', 'delivery'), 1.621360559881106),
#  (('2', 'using'), 1.6193480099231465),
#  (('set', 'new'), 1.6158260474967174),
#  (('set', 'use'), 1.6158260474967174),
#  (('delivery', 'port'), 1.6112978100913085),
#  (('ton', 'new'), 1.6102915351123288),
#  (('8', 'low'), 1.6077758476648796),
#  (('days', 'deliver'), 1.6032476102594708),
#  (('days', 'ring'), 1.6032476102594708),
#  (('set', 'blood'), 1.5999772165777866),
#  (('light', 'pump'), 1.5992225103435518),
#  (('power', 'pump'), 1.5992225103435518),
#  (('min', 'low'), 1.5982162353645721),
#  (('time', 'ear'), 1.5962036854066124),
#  (('new', 'blood'), 1.5936879979591632),
#  (('using', 'red'), 1.5911723105117137),
#  (('4', 'liver'), 1.5909207417669688),
#  (('low', 'ear'), 1.5886566230642645),
#  (('low', 'error'), 1.5886566230642645),
#  (('9', 'ring'), 1.5871472105957949),
#  (('ring', 'read'), 1.5871472105957949),
#  (('4', 'due'), 1.586644073106305),
#  (('0', 'low'), 1.5790970107639568),
#  (('change', 'low'), 1.5790970107639568),
#  (('low', 'change'), 1.5790970107639568),
#  (('one', 'liver'), 1.5743172046138032),
#  (('cha', 'ring'), 1.571046810932119),
#  (('deliver', 'issue'), 1.571046810932119),
#  (('hang', 'ring'), 1.571046810932119),
#  (('ring', 'rate'), 1.571046810932119),
#  (('sit', 'ring'), 1.571046810932119),
#  (('one', 'due'), 1.5695373984636494),
#  (('delivery', 'due'), 1.5609840611423216),
#  (('high', 'read'), 1.5554495487579332),
#  (('deliver', 'alarm'), 1.5549464112684432),
#  (('ring', 'alarm'), 1.5549464112684432),
#  (('delivery', 'time'), 1.5509213113525244),
#  (('time', 'delivery'), 1.5509213113525244),
#  (('set', 'time'), 1.5418648365417065),
#  (('ring', 'led'), 1.5388460116047673),
#  (('multiple', 'pump'), 1.5328083617308887),
#  (('set', 'low'), 1.5312989492624192),
#  (('2', 'high'), 1.5241830065359476),
#  (('8', 'deliver'), 1.5227456119410916),
#  (('8', 'ring'), 1.5227456119410916),
#  (('low', 'new'), 1.5217393369621117),
#  (('new', 'low'), 1.5217393369621117),
#  (('arm', 'deliver'), 1.49054481261374),
#  (('deliver', 'error'), 1.49054481261374),
#  (('ring', 'error'), 1.49054481261374),
#  (('change', 'ring'), 1.474444412950064),
#  (('ring', 'change'), 1.474444412950064),
#  (('4', 'deliver'), 1.4583440132863883),
#  (('4', 'ring'), 1.4583440132863883),
#  (('one', 'deliver'), 1.4261432139590364),
#  (('low', 'liver'), 1.416583601658729),
#  (('bar', 'plunger'), 1.4129811322533798),
#  (('going', 'signal'), 1.4129811322533798),
#  (('bar', 'lung'), 1.4123649171935222),
#  (('different', 'missing'), 1.4123649171935222),
#  (('years', 'prime'), 1.4123649171935222),
#  (('done', 'reservoir'), 1.4117487021336648),
#  (('going', 'difficult'), 1.4117487021336648),
#  (('setting', 'settings'), 1.4117487021336648),
#  (('small', 'control'), 1.411440594603736),
#  (('12', 'short'), 1.4111324870738071),
#  (('inside', 'side'), 1.4111324870738071),
#  (('tai', 'results'), 1.4111324870738071),
#  (('abdominal', 'switch'), 1.4105162720139497),
#  (('inside', 'contact'), 1.4105162720139497),
#  (('play', 'segment'), 1.4105162720139497),
#  (('running', 'run'), 1.4105162720139497),
#  (('small', 'difficult'), 1.4105162720139497),
#  (('sugar', 'block'), 1.4105162720139497),
#  (('sugar', 'blockage'), 1.4105162720139497),
#  (('sugar', 'problems'), 1.4105162720139497),
#  (('go', 'signal'), 1.409900056954092),
#  (('cat', 'block'), 1.4095919494241633),
#  (('cat', 'blockage'), 1.4095919494241633),
#  (('minute', 'short'), 1.4095919494241633),
#  (('12', 'unit'), 1.4092838418942344),
#  (('area', 'stomach'), 1.4092838418942344),
#  (('days', 'lot'), 1.4092838418942344),
#  (('different', 'area'), 1.4092838418942344),
#  (('sugar', 'problem'), 1.4092838418942344),
#  (('sugar', 'test'), 1.4092838418942344),
#  (('9', 'lot'), 1.408667626834377),
#  (('back', 'injection'), 1.408667626834377),
#  (('event', 'block'), 1.408667626834377),
#  (('event', 'blockage'), 1.408667626834377),
#  (('small', 'result'), 1.408667626834377),
#  (('11', 'mount'), 1.4080514117745195),
#  (('car', 'site'), 1.4080514117745195),
#  (('cat', 'test'), 1.4080514117745195),
#  (('front', 'button'), 1.4080514117745195),
#  (('going', 'without'), 1.4080514117745195),
#  (('ice', 'device'), 1.4080514117745195),
#  (('ping', 'syringe'), 1.4080514117745195),
#  (('press', 'button'), 1.4080514117745195),
#  (('running', 'without'), 1.4080514117745195),
#  (('without', 'signal'), 1.4080514117745195),
#  (('go', 'cord'), 1.4077433042445906),
#  (('small', 'end'), 1.4077433042445906),
#  (('years', 'end'), 1.4077433042445906),
#  (('abdominal', 'nausea'), 1.4068189816548042),
#  (('abdominal', 'vomiting'), 1.4068189816548042),
#  (('area', 'missing'), 1.4068189816548042),
#  (('area', 'skin'), 1.4068189816548042),
#  (('back', 'problem'), 1.4068189816548042),
#  (('car', 'contact'), 1.4068189816548042),
#  (('child', 'event'), 1.4068189816548042),
#  (('days', 'cord'), 1.4068189816548042),
#  (('days', 'dent'), 1.4068189816548042),
#  (('days', 'injection'), 1.4068189816548042),
#  (('days', 'switch'), 1.4068189816548042),
#  (('event', 'test'), 1.4068189816548042),
#  (('large', 'leak'), 1.4068189816548042),
#  (('ski', 'area'), 1.4068189816548042),
#  (('sugar', 'event'), 1.4068189816548042),
#  (('lock', 'dose'), 1.4065108741248755),
#  (('mini', 'mount'), 1.4065108741248755),
#  (('work', 'side'), 1.4065108741248755),
#  (('5', 'another'), 1.4062027665949466),
#  (('5', 'mode'), 1.4062027665949466),
#  (('5', 'results'), 1.4062027665949466),
#  (('8', 'lot'), 1.4062027665949466),
#  (('going', 'delivered'), 1.4062027665949466),
#  (('20', 'block'), 1.4058946590650179),
#  (('20', 'blockage'), 1.4058946590650179),
#  (('20', 'current'), 1.4058946590650179),
#  (('20', 'nut'), 1.4058946590650179),
#  (('9', 'dent'), 1.4058946590650179),
#  (('9', 'form'), 1.4058946590650179),
#  (('car', 'follow'), 1.4055865515350892),
#  (('child', 'end'), 1.4055865515350892),
#  (('go', 'difficult'), 1.4055865515350892),
#  (('min', 'results'), 1.4055865515350892),
#  (('24', 'issue'), 1.4049703364752317),
#  (('ax', 'ear'), 1.4049703364752317),
#  (('back', 'mount'), 1.4049703364752317),
#  (('back', 'side'), 1.4049703364752317),
#  (('back', 'site'), 1.4049703364752317),
#  (('delivering', 'form'), 1.4049703364752317),
#  (('ice', 'problems'), 1.4049703364752317),
#  (('ice', 'skin'), 1.4049703364752317),
#  (('lock', 'event'), 1.4049703364752317),
#  (('lock', 'insert'), 1.4049703364752317),
#  (('play', 'side'), 1.4049703364752317),
#  (('sit', 'cord'), 1.4049703364752317),
#  (('sit', 'injection'), 1.4049703364752317),
#  (('tai', 'contact'), 1.4049703364752317),
#  (('tai', 'result'), 1.4049703364752317),
#  (('0', 'results'), 1.4043541214153739),
#  (('15', 'unit'), 1.4043541214153739),
#  (('7', 'lot'), 1.4043541214153739),
#  (('7', 'manufacturing'), 1.4043541214153739),
#  (('7', 'record'), 1.4043541214153739),
#  (('abdominal', 'screen'), 1.4043541214153739),
#  (('days', 'abdominal'), 1.4043541214153739),
#  (('metal', 'needle'), 1.4043541214153739),
#  (('program', 'tip'), 1.4043541214153739),
#  (('6', 'nut'), 1.4040460138854454),
#  (('place', 'side'), 1.4034297988255877),
#  (('tai', 'end'), 1.4034297988255877),
#  (('15', 'read'), 1.403121691295659),
#  (('20', 'test'), 1.403121691295659),
#  (('9', 'disc'), 1.403121691295659),
#  (('9', 'disconnect'), 1.403121691295659),
#  (('abdominal', 'read'), 1.403121691295659),
#  (('chi', 'event'), 1.403121691295659),
#  (('disco', 'infusion'), 1.403121691295659),
#  (('hand', 'led'), 1.403121691295659),
#  (('one', 'stent'), 1.4025054762358014),
#  (('5', 'form'), 1.4021973687058726),
#  (('5', 'problems'), 1.4021973687058726),
#  (('8', 'current'), 1.4021973687058726),
#  (('8', 'dent'), 1.4021973687058726),
#  (('8', 'form'), 1.4021973687058726),
#  (('10', 'unit'), 1.4018892611759437),
#  (('cha', 'cap'), 1.4018892611759437),
#  (('cha', 'pin'), 1.4018892611759437),
#  (('days', 'site'), 1.4018892611759437),
#  (('delivering', 'readings'), 1.4018892611759437),
#  (('delivery', 'inaccurate delivery'), 1.4018892611759437),
#  (('hang', 'cap'), 1.4018892611759437),
#  (('hang', 'pin'), 1.4018892611759437),
#  (('ice', 'problem'), 1.4018892611759437),
#  (('self', 'working'), 1.4018892611759437),
#  (('setting', 'button'), 1.4018892611759437),
#  (('sit', 'cap'), 1.4018892611759437),
#  (('sit', 'difficult'), 1.4018892611759437),
#  (('sit', 'pin'), 1.4018892611759437),
#  (('sugar', 'rate'), 1.4018892611759437),
#  (('without', 'difficult'), 1.4018892611759437),
#  (('chi', 'end'), 1.4012730461160863),
#  (('event', 'end'), 1.4012730461160863),
#  (('go', 'contact'), 1.4012730461160863),
#  (('go', 'insert'), 1.4012730461160863),
#  (('min', 'control'), 1.4012730461160863),
#  (('min', 'problems'), 1.4012730461160863),
#  (('min', 'switch'), 1.4012730461160863),
#  (('set', 'apparent'), 1.4012730461160863),
#  (('set', 'detachment'), 1.4012730461160863),
#  (('set', 'lot'), 1.4012730461160863),
#  (('set', 'settings'), 1.4012730461160863),
#  (('ski', 'cannula'), 1.4012730461160863),
#  (('6', 'diabetic'), 1.4006568310562286),
#  (('abdominal', 'alarm'), 1.4006568310562286),
#  (('away', 'use'), 1.4006568310562286),
#  (('new', 'batch'), 1.4006568310562286),
#  (('ton', 'stent'), 1.4006568310562286),
#  (('ton', 'sticking'), 1.4006568310562286),
#  (('20', 'dose'), 1.4003487235263),
#  (('arm', 'control'), 1.4003487235263),
#  (('arm', 'switch'), 1.4003487235263),
#  (('lock', 'ugh'), 1.4003487235263),
#  (('1', 'record'), 1.4000406159963712),
#  (('0', 'block'), 1.3994244009365135),
#  (('0', 'blockage'), 1.3994244009365135),
#  (('0', 'current'), 1.3994244009365135),
#  (('0', 'dent'), 1.3994244009365135),
#  (('0', 'form'), 1.3994244009365135),
#  (('0', 'injection'), 1.3994244009365135),
#  (('0', 'nut'), 1.3994244009365135),
#  (('0', 'problems'), 1.3994244009365135),
#  (('7', 'cord'), 1.3994244009365135),
#  (('7', 'dent'), 1.3994244009365135),
#  (('7', 'form'), 1.3994244009365135),
#  (('back', 'unit'), 1.3994244009365135),
#  (('chi', 'tip'), 1.3994244009365135),
#  (('days', 'event'), 1.3994244009365135),
#  (('days', 'nausea'), 1.3994244009365135),
#  (('play', 'screen'), 1.3994244009365135),
#  (('press', 'port'), 1.3994244009365135),
#  (('go', 'follow'), 1.3991162934065848),
#  (('cat', 'rate'), 1.398808185876656),
#  (('cat', 'without'), 1.398808185876656),
#  (('cha', 'syringe'), 1.398808185876656),
#  (('delivering', 'mount'), 1.398808185876656),
#  (('going', 'blood'), 1.398808185876656),
#  (('hang', 'syringe'), 1.398808185876656),
#  (('ice', 'side'), 1.398808185876656),
#  (('lock', 'issue'), 1.398808185876656),
#  (('lock', 'without'), 1.398808185876656),
#  (('sit', 'found'), 1.398808185876656),
#  (('working', 'side'), 1.398808185876656),
#  (('4', 'current'), 1.3985000783467272),
#  (('4', 'occlusion'), 1.3985000783467272),
#  (('11', 'delivered'), 1.3981919708167985),
#  (('5', 'problem'), 1.3981919708167985),
#  (('8', 'clear'), 1.3981919708167985),
#  (('child', 'delivered'), 1.3981919708167985),
#  (('20', 'event'), 1.397575755756941),
#  (('20', 'head'), 1.397575755756941),
#  (('20', 'insert'), 1.397575755756941),
#  (('20', 'vomiting'), 1.397575755756941),
#  (('back', 'infusion'), 1.397575755756941),
#  (('level', 'control'), 1.397575755756941),
#  (('level', 'problems'), 1.397575755756941),
#  (('2', 'lot'), 1.3969595406970834),
#  (('2', 'manufacturing'), 1.3969595406970834),
#  (('2', 'mode'), 1.3969595406970834),
#  (('2', 'results'), 1.3969595406970834),
#  (('car', 'cannula'), 1.3969595406970834),
#  (('days', 'end'), 1.3969595406970834),
#  (('days', 'follow'), 1.3969595406970834),
#  (('go', 'unit'), 1.3969595406970834),
#  (('min', 'abdominal'), 1.3969595406970834),
#  (('one', 'cord'), 1.3966514331671547),
#  (('one', 'injection'), 1.3966514331671547),
#  (('arm', 'abdominal'), 1.3957271105773683),
#  (('back', 'button'), 1.3957271105773683),
#  (('car', 'ear'), 1.3957271105773683),
#  (('chi', 'without'), 1.3957271105773683),
#  (('child', 'ear'), 1.3957271105773683),
#  (('delivery', 'block'), 1.3957271105773683),
#  (('delivery', 'blockage'), 1.3957271105773683),
#  (('delivery', 'inaccurate'), 1.3957271105773683),
#  (('ice', 'contact'), 1.3957271105773683),
#  (('motor', 'error'), 1.3957271105773683),
#  (('run', 'without'), 1.3957271105773683),
#  (('setting', 'ear'), 1.3957271105773683),
#  (('sit', 'contact'), 1.3957271105773683),
#  (('sit', 'insert'), 1.3957271105773683),
#  (('sit', 'result'), 1.3957271105773683),
#  (('without', 'run'), 1.3957271105773683),
#  (('go', 'ugh'), 1.394802787987582),
#  (('place', 'infusion'), 1.394802787987582),
#  (('place', 'ugh'), 1.394802787987582),
#  (('set', 'dent'), 1.394802787987582),
#  (('set', 'injection'), 1.394802787987582),
#  (('0', 'disc'), 1.394494680457653),
#  (('0', 'disconnect'), 1.394494680457653),
#  (('0', 'readings'), 1.394494680457653),
#  (('0', 'test'), 1.394494680457653),
#  (('7', 'cap'), 1.394494680457653),
#  (('7', 'pin'), 1.394494680457653),
#  (('area', 'needle'), 1.394494680457653),
#  (('change', 'cap'), 1.394494680457653),
#  (('change', 'pin'), 1.394494680457653),
#  (('days', 'light'), 1.394494680457653),
#  (('disco', 'using'), 1.394494680457653),
#  (('ping', 'change'), 1.394494680457653),
#  (('setting', 'using'), 1.394494680457653),
#  (('using', 'disc'), 1.394494680457653),
#  (('using', 'disconnect'), 1.394494680457653),
#  (('work', 'battery'), 1.3941865729277243),
#  (('6', 'acidosis'), 1.3938784653977956),
#  (('6', 'contact'), 1.3938784653977956),
#  (('6', 'head'), 1.3938784653977956),
#  (('6', 'nausea'), 1.3938784653977956),
#  (('cart', 'new'), 1.3938784653977956),
#  (('going', 'liver'), 1.3938784653977956),
#  (('small', 'use'), 1.3938784653977956),
#  (('ton', 'cord'), 1.3938784653977956),
#  (('ton', 'not working'), 1.3938784653977956),
#  (('years', 'use'), 1.3938784653977956),
#  (('4', 'clear'), 1.393262250337938),
#  (('1', 'cord'), 1.3929541428080092),
#  (('1', 'current'), 1.3929541428080092),
#  (('12', 'red'), 1.3926460352780805),
#  (('cha', 'follow'), 1.3926460352780805),
#  (('go', 'rate'), 1.3926460352780805),
#  (('going', 'red'), 1.3926460352780805),
#  (('hang', 'follow'), 1.3926460352780805),
#  (('min', 'dose'), 1.3926460352780805),
#  (('place', 'working'), 1.3926460352780805),
#  (('running', 'red'), 1.3926460352780805),
#  (('sit', 'end'), 1.3926460352780805),
#  (('sit', 'follow'), 1.3926460352780805),
#  (('20', 'light'), 1.3920298202182229),
#  (('9', 'unit'), 1.3920298202182229),
#  (('back', 'led'), 1.3920298202182229),
#  (('chi', 'multiple'), 1.3920298202182229),
#  (('days', 'read'), 1.3920298202182229),
#  (('different', 'time'), 1.3920298202182229),
#  (('event', 'led'), 1.3920298202182229),
#  (('level', 'problem'), 1.3920298202182229),
#  (('light', 'infusion'), 1.3920298202182229),
#  (('time', 'apparent'), 1.3920298202182229),
#  (('time', 'mode'), 1.3920298202182229),
#  (('time', 'prime'), 1.3920298202182229),
#  (('time', 'results'), 1.3920298202182229),
#  (('10', 'ear'), 1.3911054976284365),
#  (('arm', 'syringe'), 1.3911054976284365),
#  (('tai', 'ear'), 1.3911054976284365),
#  (('work', 'ear'), 1.3911054976284365),
#  (('low', 'manufacturing'), 1.3907973900985078),
#  (('low', 'stent'), 1.3907973900985078),
#  (('one', 'difficult'), 1.3907973900985078),
#  (('one', 'disc'), 1.3907973900985078),
#  (('one', 'disconnect'), 1.3907973900985078),
#  (('one', 'reservoir'), 1.3907973900985078),
#  (('one', 'unresponsive'), 1.3907973900985078),
#  (('running', 'low'), 1.3907973900985078),
#  (('go', 'remove'), 1.390489282568579),
#  (('5', 'result'), 1.3901811750386501),
#  (('5', 'vomiting'), 1.3901811750386501),
#  (('8', 'contact'), 1.3901811750386501),
#  (('chi', 'delivered'), 1.3901811750386501),
#  (('0', 'mount'), 1.3895649599787927),
#  (('0', 'site'), 1.3895649599787927),
#  (('7', 'mount'), 1.3895649599787927),
#  (('cha', 'light'), 1.3895649599787927),
#  (('cha', 'tip'), 1.3895649599787927),
#  (('cha', 'unit'), 1.3895649599787927),
#  (('change', 'syringe'), 1.3895649599787927),
#  (('child', 'delivery'), 1.3895649599787927),
#  (('delivery', 'test'), 1.3895649599787927),
#  (('hang', 'light'), 1.3895649599787927),
#  (('hang', 'tip'), 1.3895649599787927),
#  (('hang', 'unit'), 1.3895649599787927),
#  (('ice', 'area'), 1.3895649599787927),
#  (('lock', 'using'), 1.3895649599787927),
#  (('sit', 'light'), 1.3895649599787927),
#  (('sugar', 'delivery'), 1.3895649599787927),
#  (('9', 'read'), 1.3892568524488638),
#  (('2', 'block'), 1.3883325298590774),
#  (('2', 'blockage'), 1.3883325298590774),
#  (('2', 'cord'), 1.3883325298590774),
#  (('2', 'current'), 1.3883325298590774),
#  (('2', 'diabetic ketoacidosis'), 1.3883325298590774),
#  (('2', 'form'), 1.3883325298590774),
#  (('2', 'injection'), 1.3883325298590774),
#  (('2', 'nut'), 1.3883325298590774),
#  (('min', 'contact'), 1.3883325298590774),
#  (('min', 'head'), 1.3883325298590774),
#  (('min', 'result'), 1.3883325298590774),
#  (('min', 'vomiting'), 1.3883325298590774),
#  (('set', 'clear'), 1.3883325298590774),
#  (('set', 'disc'), 1.3883325298590774),
#  (('set', 'disconnect'), 1.3883325298590774),
#  (('set', 'problem'), 1.3883325298590774),
#  (('4', 'found'), 1.3880244223291487),
#  (('abdominal', 'use'), 1.3871000997393625),
#  (('car', 'new'), 1.3871000997393625),
#  (('days', 'alarm'), 1.3871000997393625),
#  (('days', 'remove'), 1.3871000997393625),
#  (('new', 'clear'), 1.3871000997393625),
#  (('new', 'reservoir'), 1.3871000997393625),
#  (('program', 'use'), 1.3871000997393625),
#  (('sugar', 'use'), 1.3871000997393625),
#  (('ton', 'clear'), 1.3871000997393625),
#  (('ton', 'difficult'), 1.3871000997393625),
#  (('ton', 'stick'), 1.3871000997393625),
#  (('20', 'button'), 1.386483884679505),
#  (('20', 'issue'), 1.386483884679505),
#  (('20', 'rate'), 1.386483884679505),
#  (('20', 'without'), 1.386483884679505),
#  (('arm', 'nausea'), 1.386483884679505),
#  (('back', 'ear'), 1.386483884679505),
#  (('delivering', 'read'), 1.386483884679505),
#  (('delivering', 'ugh'), 1.386483884679505),
#  (('hang', 'infusion'), 1.386483884679505),
#  (('level', 'dose'), 1.386483884679505),
#  (('play', 'ear'), 1.386483884679505),
#  (('without', 'ugh'), 1.386483884679505),
#  (('5', 'end'), 1.3861757771495762),
#  (('8', 'follow'), 1.3861757771495762),
#  (('go', 'delivered'), 1.3861757771495762),
#  (('place', 'delivered'), 1.3861757771495762),
#  (('1', 'disc'), 1.3858676696196472),
#  (('1', 'disconnect'), 1.3858676696196472),
#  (('1', 'problem'), 1.3858676696196472),
#  (('one', 'found'), 1.3849433470298609),
#  (('one', 'site'), 1.3849433470298609),
#  (('0', 'event'), 1.3846352394999322),
#  (('0', 'head'), 1.3846352394999322),
#  (('0', 'insert'), 1.3846352394999322),
#  (('0', 'result'), 1.3846352394999322),
#  (('0', 'vomiting'), 1.3846352394999322),
#  (('7', 'nausea'), 1.3846352394999322),
#  (('7', 'result'), 1.3846352394999322),
#  (('7', 'vomiting'), 1.3846352394999322),
#  (('back', 'using'), 1.3846352394999322),
#  (('child', 'port'), 1.3846352394999322),
#  (('disco', 'port'), 1.3846352394999322),
#  (('sugar', 'port'), 1.3846352394999322),
#  (('using', 'insert'), 1.3846352394999322),
#  (('min', 'end'), 1.3840190244400745),
#  (('min', 'follow'), 1.3840190244400745),
#  (('20', 'alarm'), 1.3837109169101458),
#  (('6', 'read'), 1.3837109169101458),
#  ...]

# %%
insulin_problems = ['hospitalised']

# %%
Counter([t for t in tokenizer.tokenize(" ".join(insulin_df['Event description'].str.lower())) if t not in stopwords.words('english')]).most_common()
# Out:
# [('pump', 131),
#  ('patient', 100),
#  ('customer', 74),
#  ('insulin', 73),
#  ('blood', 50),
#  ('glucose', 45),
#  ('high', 44),
#  ('due', 34),
#  ('levels', 27),
#  ('hospitalised', 23),
#  ('battery', 22),
#  ('hospital', 21),
#  ('reported', 19),
#  ('delivered', 19),
#  ('set', 18),
#  ('needle', 18),
#  ('bg', 17),
#  ('infusion', 17),
#  ('mmol', 16),
#  ('l', 16),
#  ('cannula', 15),
#  ('new', 15),
#  ('time', 15),
#  ('error', 15),
#  ('removed', 13),
#  ('e', 13),
#  ('advised', 12),
#  ('low', 12),
#  ('days', 12),
#  ('delivery', 12),
#  ('screen', 12),
#  ('units', 12),
#  ('delivering', 12),
#  ('admitted', 11),
#  ('bolus', 11),
#  ('ketones', 11),
#  ('later', 10),
#  ('alarm', 10),
#  ('day', 10),
#  ('experienced', 10),
#  ('times', 9),
#  ('buttons', 9),
#  ('states', 9),
#  ('button', 9),
#  ('level', 8),
#  ('errors', 8),
#  ('animas', 8),
#  ('multiple', 8),
#  ('display', 8),
#  ('child', 7),
#  ('dka', 7),
#  ('called', 7),
#  ('two', 7),
#  ('occurred', 7),
#  ('area', 7),
#  ('would', 7),
#  ('following', 7),
#  ('occlusion', 7),
#  ('motor', 7),
#  ('stated', 7),
#  ('back', 7),
#  ('combo', 7),
#  ('elevated', 7),
#  ('using', 6),
#  ('incident', 6),
#  ('readings', 6),
#  ('giving', 6),
#  ('also', 6),
#  ('issues', 6),
#  ('working', 6),
#  ('without', 6),
#  ('found', 6),
#  ('issue', 6),
#  ('however', 6),
#  ('morning', 6),
#  ('hospitalisation', 6),
#  ('unwell', 6),
#  ('vomiting', 6),
#  ('nausea', 6),
#  ('bgl', 6),
#  ('diabetic', 5),
#  ('ketoacidosis', 5),
#  ('approximately', 5),
#  ('tubing', 5),
#  ('advises', 5),
#  ('given', 5),
#  ('skin', 5),
#  ('noticed', 5),
#  ('administered', 5),
#  ('site', 5),
#  ('used', 5),
#  ('sugar', 5),
#  ('reservoir', 5),
#  ('first', 5),
#  ('began', 5),
#  ('hospitalized', 5),
#  ('night', 5),
#  ('within', 5),
#  ('hours', 5),
#  ('months', 5),
#  ('missing', 5),
#  ('showed', 5),
#  ('sponsor', 5),
#  ('complained', 5),
#  ('amount', 5),
#  ('next', 5),
#  ('inserted', 5),
#  ('basal', 5),
#  ('alleged', 5),
#  ('cartridge', 5),
#  ('warning', 5),
#  ('feels', 5),
#  ('check', 5),
#  ('power', 5),
#  ('lot', 4),
#  ('x', 4),
#  ('attached', 4),
#  ('still', 4),
#  ('presented', 4),
#  ('reading', 4),
#  ('leaks', 4),
#  ('change', 4),
#  ('state', 4),
#  ('unable', 4),
#  ('problems', 4),
#  ('device', 4),
#  ('reporting', 4),
#  ('years', 4),
#  ('ambulance', 4),
#  ('second', 4),
#  ('date', 4),
#  ('nurse', 4),
#  ('unresponsive', 4),
#  ('last', 4),
#  ('experiencing', 4),
#  ('rewind', 4),
#  ('ago', 4),
#  ('received', 4),
#  ('pm', 4),
#  ('one', 4),
#  ('insitu', 4),
#  ('death', 4),
#  ('claims', 4),
#  ('made', 4),
#  ('aware', 4),
#  ('spirit', 4),
#  ('read', 4),
#  ('pixels', 4),
#  ('said', 4),
#  ('developed', 3),
#  ('unconscious', 3),
#  ('took', 3),
#  ('gp', 3),
#  ('canula', 3),
#  ('extra', 3),
#  ('hyperglycaemia', 3),
#  ('meter', 3),
#  ('hi', 3),
#  ('headset', 3),
#  ('weeks', 3),
#  ('changed', 3),
#  ('adhesive', 3),
#  ('hour', 3),
#  ('plastic', 3),
#  ('amounts', 3),
#  ('flexlink', 3),
#  ('correctly', 3),
#  ('leaking', 3),
#  ('broken', 3),
#  ('syringe', 3),
#  ('use', 3),
#  ('syringes', 3),
#  ('reports', 3),
#  ('supplied', 3),
#  ('regarding', 3),
#  ('cap', 3),
#  ('plunger', 3),
#  ('difficult', 3),
#  ('control', 3),
#  ('cause', 3),
#  ('tried', 3),
#  ('causing', 3),
#  ('diabetes', 3),
#  ('hypoglycaemia', 3),
#  ('believes', 3),
#  ('keypad', 3),
#  ('replaced', 3),
#  ('faulty', 3),
#  ('blockage', 3),
#  ('despite', 3),
#  ('results', 3),
#  ('turned', 3),
#  ('taken', 3),
#  ('bent', 3),
#  ('suspected', 3),
#  ('brand', 3),
#  ('medtronic', 3),
#  ('sent', 3),
#  ('failed', 3),
#  ('three', 3),
#  ('deliver', 3),
#  ('contacted', 3),
#  ('contact', 3),
#  ('different', 3),
#  ('alert', 3),
#  ('message', 3),
#  ('boluses', 3),
#  ('functioning', 3),
#  ('passed', 3),
#  ('maximum', 3),
#  ('checked', 3),
#  ('short', 3),
#  ('could', 3),
#  ('sugars', 3),
#  ('connected', 3),
#  ('disconnected', 3),
#  ('turning', 3),
#  ('lower', 3),
#  ('period', 3),
#  ('went', 3),
#  ('iv', 3),
#  ('rate', 3),
#  ('blank', 3),
#  ('showing', 3),
#  ('interrupt', 3),
#  ('cleared', 3),
#  ('side', 3),
#  ('w', 3),
#  ('data', 3),
#  ('well', 3),
#  ('woke', 3),
#  ('episode', 3),
#  ('inaccurate', 3),
#  ('detachment', 3),
#  ('cozmo', 2),
#  ('bgs', 2),
#  ('minutes', 2),
#  ('mother', 2),
#  ('boy', 2),
#  ('cleo', 2),
#  ('sets', 2),
#  ('australia', 2),
#  ('tissue', 2),
#  ('son', 2),
#  ('local', 2),
#  ('metal', 2),
#  ('dose', 2),
#  ('large', 2),
#  ('inserting', 2),
#  ('apparently', 2),
#  ('occurring', 2),
#  ('couple', 2),
#  ('getting', 2),
#  ('irritation', 2),
#  ('stomach', 2),
#  ('surface', 2),
#  ('small', 2),
#  ('stick', 2),
#  ('place', 2),
#  ('start', 2),
#  ('part', 2),
#  ('red', 2),
#  ('usual', 2),
#  ('caused', 2),
#  ('released', 2),
#  ('injection', 2),
#  ('batch', 2),
#  ('snapping', 2),
#  ('manufacturing', 2),
#  ('resulted', 2),
#  ('bending', 2),
#  ('result', 2),
#  ('makes', 2),
#  ('likely', 2),
#  ('client', 2),
#  ('barrel', 2),
#  ('difficulties', 2),
#  ('every', 2),
#  ('emergency', 2),
#  ('type', 2),
#  ('treated', 2),
#  ('model', 2),
#  ('becoming', 2),
#  ('stuck', 2),
#  ('going', 2),
#  ('reason', 2),
#  ('throughout', 2),
#  ('became', 2),
#  ('signal', 2),
#  ('often', 2),
#  ('whether', 2),
#  ('severe', 2),
#  ('heart', 2),
#  ('cannulas', 2),
#  ('several', 2),
#  ('hypoglycaemic', 2),
#  ('contacting', 2),
#  ('us', 2),
#  ('number', 2),
#  ('random', 2),
#  ('failure', 2),
#  ('left', 2),
#  ('initial', 2),
#  ('carer', 2),
#  ('inconclusive', 2),
#  ('another', 2),
#  ('inside', 2),
#  ('sticking', 2),
#  ('done', 2),
#  ('properly', 2),
#  ('away', 2),
#  ('pushed', 2),
#  ('setting', 2),
#  ('point', 2),
#  ('overdose', 2),
#  ('evening', 2),
#  ('felt', 2),
#  ('half', 2),
#  ('technical', 2),
#  ('support', 2),
#  ('rising', 2),
#  ('responding', 2),
#  ('appear', 2),
#  ('placed', 2),
#  ('staff', 2),
#  ('evaluated', 2),
#  ('indicating', 2),
#  ('looked', 2),
#  ('provided', 2),
#  ('admission', 2),
#  ('right', 2),
#  ('report', 2),
#  ('absence', 2),
#  ('test', 2),
#  ('running', 2),
#  ('get', 2),
#  ('occluding', 2),
#  ('cannot', 2),
#  ('ok', 2),
#  ('front', 2),
#  ('lost', 2),
#  ('warnings', 2),
#  ('settings', 2),
#  ('cutomer', 2),
#  ('feeling', 2),
#  ('alarming', 2),
#  ('switched', 2),
#  ('abdominal', 2),
#  ('pain', 2),
#  ('case', 2),
#  ('segments', 2),
#  ('recently', 2),
#  ('menu', 2),
#  ('see', 2),
#  ('empty', 2),
#  ('powered', 2),
#  ('frequently', 2),
#  ('around', 2),
#  ('non', 2),
#  ('responsive', 2),
#  ('via', 2),
#  ('hypoglycemic', 2),
#  ('loan', 2),
#  ('lock', 2),
#  ('vibe', 2),
#  ('alarms', 2),
#  ('failures', 2),
#  ('batteries', 2),
#  ('cracks', 2),
#  ('damage', 2),
#  ('self', 2),
#  ('noted', 2),
#  ('treatment', 2),
#  ('hospitalization', 2),
#  ('detached', 2),
#  ('happened', 2),
#  ('kinked', 2),
#  ('loaner', 1),
#  ('early', 1),
#  ('mmo', 1),
#  ('juice', 1),
#  ('jelly', 1),
#  ('beans', 1),
#  ('blacked', 1),
#  ('hit', 1),
#  ('head', 1),
#  ('door', 1),
#  ('hinge', 1),
#  ('medical', 1),
#  ('specialties', 1),
#  ('advise', 1),
#  ('incidents', 1),
#  ('involving', 1),
#  ('peeled', 1),
#  ('mm', 1),
#  ('teflon', 1),
#  ('subcutaneous', 1),
#  ('gave', 1),
#  ('anaesthetic', 1),
#  ('tweezers', 1),
#  ('hub', 1),
#  ('implying', 1),
#  ('able', 1),
#  ('calculate', 1),
#  ('correction', 1),
#  ('based', 1),
#  ('numerical', 1),
#  ('values', 1),
#  ('introducer', 1),
#  ('body', 1),
#  ('rapid', 1),
#  ('plaster', 1),
#  ('slight', 1),
#  ('bleeding', 1),
#  ('bumps', 1),
#  ('stay', 1),
#  ('lift', 1),
#  ('top', 1),
#  ('hard', 1),
#  ('sore', 1),
#  ('regularly', 1),
#  ('wet', 1),
#  ('shorter', 1),
#  ('unintentionally', 1),
#  ('injury', 1),
#  ('consumer', 1),
#  ('broke', 1),
#  ('arm', 1),
#  ('attempting', 1),
#  ('intravenous', 1),
#  ('drug', 1),
#  ('users', 1),
#  ('rejecting', 1),
#  ('exchange', 1),
#  ('programs', 1),
#  ('say', 1),
#  ('blunt', 1),
#  ('flexible', 1),
#  ('tips', 1),
#  ('people', 1),
#  ('arms', 1),
#  ('recent', 1),
#  ('terumo', 1),
#  ('ml', 1),
#  ('g', 1),
#  ('numerous', 1),
#  ('complaints', 1),
#  ('wide', 1),
#  ('factors', 1),
#  ('sharpness', 1),
#  ('flexibility', 1),
#  ('situ', 1),
#  ('piercing', 1),
#  ('stiffness', 1),
#  ('seems', 1),
#  ('easier', 1),
#  ('bend', 1),
#  ('break', 1),
#  ('flex', 1),
#  ('hence', 1),
#  ('making', 1),
#  ('wings', 1),
#  ('smaller', 1),
#  ('handling', 1),
#  ('give', 1),
#  ('receive', 1),
#  ('unit', 1),
#  ('administer', 1),
#  ('connections', 1),
#  ('disconnect', 1),
#  ('stock', 1),
#  ('outages', 1),
#  ('consumable', 1),
#  ('items', 1),
#  ('required', 1),
#  ('order', 1),
#  ('usable', 1),
#  ('integrated', 1),
#  ('glucometre', 1),
#  ('accessible', 1),
#  ('essential', 1),
#  ('management', 1),
#  ('inability', 1),
#  ('obtain', 1),
#  ('doses', 1),
#  ('accident', 1),
#  ('monitored', 1),
#  ('pressed', 1),
#  ('accidentally', 1),
#  ('recognise', 1),
#  ('full', 1),
#  ('priming', 1),
#  ('floor', 1),
#  ('five', 1),
#  ('seemed', 1),
#  ('year', 1),
#  ('develop', 1),
#  ('eg', 1),
#  ('etc', 1),
#  ('worse', 1),
#  ('eventually', 1),
#  ('recalling', 1),
#  ('unfortunately', 1),
#  ('replacement', 1),
#  ('constantly', 1),
#  ('turns', 1),
#  ('needs', 1),
#  ('primed', 1),
#  ('sends', 1),
#  ('signals', 1),
#  ('assuring', 1),
#  ('affected', 1),
#  ('failing', 1),
#  ('health', 1),
#  ('certainly', 1),
#  ('reflect', 1),
#  ('consequence', 1),
#  ('unsure', 1),
#  ('vigilant', 1),
#  ('tester', 1),
#  ('indicate', 1),
#  ('accurately', 1),
#  ('machine', 1),
#  ('hypo', 1),
#  ('beat', 1),
#  ('hands', 1),
#  ('feet', 1),
#  ('paralytic', 1),
#  ('declared', 1),
#  ('dead', 1),
#  ('er', 1),
#  ('suspects', 1),
#  ('custustomer', 1),
#  ('crimped', 1),
#  ('tip', 1),
#  ('incurred', 1),
#  ('inexplicable', 1),
#  ('events', 1),
#  ('leading', 1),
#  ('immediate', 1),
#  ('suspension', 1),
#  ('immediately', 1),
#  ('suspended', 1),
#  ('third', 1),
#  ('precisely', 1),
#  ('manner', 1),
#  ('pumps', 1),
#  ('share', 1),
#  ('requested', 1),
#  ('driver', 1),
#  ('neria', 1),
#  ('positioned', 1),
#  ('upper', 1),
#  ('thoracic', 1),
#  ('near', 1),
#  ('scapula', 1),
#  ('uncertainty', 1),
#  ('sections', 1),
#  ('examination', 1),
#  ('apparent', 1),
#  ('redness', 1),
#  ('firm', 1),
#  ('tender', 1),
#  ('mass', 1),
#  ('identified', 1),
#  ('palpation', 1),
#  ('detect', 1),
#  ('presence', 1),
#  ('rayed', 1),
#  ('rays', 1),
#  ('ultra', 1),
#  ('sounded', 1),
#  ('informed', 1),
#  ('inflammation', 1),
#  ('settled', 1),
#  ('snapped', 1),
#  ('remained', 1),
#  ('fogging', 1),
#  ('condensation', 1),
#  ('happening', 1),
#  ('continues', 1),
#  ('take', 1),
#  ('fact', 1),
#  ('returning', 1),
#  ('replacment', 1),
#  ('arrived', 1),
#  ('needed', 1),
#  ('instal', 1),
#  ('steps', 1),
#  ('came', 1),
#  ('nothing', 1),
#  ('stays', 1),
#  ('function', 1),
#  ('aything', 1),
#  ('dependant', 1),
#  ('mellitus', 1),
#  ('past', 1),
#  ('sudden', 1),
#  ('onset', 1),
#  ('unprovoked', 1),
#  ('episodes', 1),
#  ('discovered', 1),
#  ('unprogrammed', 1),
#  ('fixed', 1),
#  ('prime', 1),
#  ('daily', 1),
#  ('user', 1),
#  ('coma', 1),
#  ('got', 1),
#  ('recurring', 1),
#  ('problem', 1),
#  ('normal', 1),
#  ('appears', 1),
#  ('estimated', 1),
#  ('zero', 1),
#  ('mistaken', 1),
#  ('rolls', 1),
#  ('default', 1),
#  ('act', 1),
#  ('recurrent', 1),
#  ('memory', 1),
#  ('parents', 1),
#  ('fatal', 1),
#  ('wearing', 1),
#  ('minimed', 1),
#  ('paradigm', 1),
#  ('veo', 1),
#  ('cgms', 1),
#  ('followed', 1),
#  ('rebound', 1),
#  ('thought', 1),
#  ('husband', 1),
#  ('put', 1),
#  ('injections', 1),
#  ('stabilised', 1),
#  ('rose', 1),
#  ('retesting', 1),
#  ('reduced', 1),
#  ('explained', 1),
#  ('event', 1),
#  ('resumed', 1),
#  ('returned', 1),
#  ('concern', 1),
#  ('slightly', 1),
#  ('kept', 1),
#  ('till', 1),
#  ('afternoon', 1),
#  ('reaching', 1),
#  ('corrections', 1),
#  ('reconnected', 1),
#  ('increase', 1),
#  ('unusually', 1),
#  ('starting', 1),
#  ('reporter', 1),
#  ('completed', 1),
#  ('feel', 1),
#  ('shortly', 1),
#  ('reportedly', 1),
#  ('glucagon', 1),
#  ('raise', 1),
#  ('attempted', 1),
#  ('load', 1),
#  ('dispensed', 1),
#  ('entire', 1),
#  ('details', 1),
#  ('circumstances', 1),
#  ('disorientated', 1),
#  ('dehydrated', 1),
#  ('confused', 1),
#  ('according', 1),
#  ('notes', 1),
#  ('ketone', 1),
#  ('present', 1),
#  ('urine', 1),
#  ('pupil', 1),
#  ('sluggish', 1),
#  ('seeing', 1),
#  ('detach', 1),
#  ('tail', 1),
#  ('meant', 1),
#  ('spike', 1),
#  ('temperature', 1),
#  ('antibiotics', 1),
#  ('intermittant', 1),
#  ('encountered', 1),
#  ('anomaly', 1),
#  ('per', 1),
#  ('coroner', 1),
#  ('unconcisous', 1),
#  ('condition', 1),
#  ('malfunction', 1),
#  ('changes', 1),
#  ('malfunctioned', 1),
#  ('repeated', 1),
#  ('alerts', 1),
#  ('allegedly', 1),
#  ('basic', 1),
#  ('troubleshooting', 1),
#  ('performed', 1),
#  ('pressure', 1),
#  ('possible', 1),
#  ('flow', 1),
#  ('notifying', 1),
#  ('inconsistently', 1),
#  ('others', 1),
#  ('lifestyle', 1),
#  ('eating', 1),
#  ('habits', 1),
#  ('flight', 1),
#  ('prompts', 1),
#  ('record', 1),
#  ('piston', 1),
#  ('moved', 1),
#  ('original', 1),
#  ('position', 1),
#  ('depleted', 1),
#  ('kink', 1),
#  ('line', 1),
#  ('think', 1),
#  ('says', 1),
#  ('mornings', 1),
#  ('fallen', 1),
#  ('temporary', 1),
#  ('interruption', 1),
#  ('less', 1),
#  ('minute', 1),
#  ('longer', 1),
#  ('beeping', 1),
#  ('vibrating', 1),
#  ('messages', 1),
#  ('history', 1),
#  ('downloading', 1),
#  ('deliveries', 1),
#  ('month', 1),
#  ('unknown', 1),
#  ('complaint', 1),
#  ('permanently', 1),
#  ('coloured', 1),
#  ('continually', 1),
#  ('registering', 1),
#  ('press', 1),
#  ('reverting', 1),
#  ('factory', 1),
#  ('pixel', 1),
#  ('partial', 1),
#  ('areas', 1),
#  ('isolated', 1),
#  ('location', 1),
#  ('locations', 1),
#  ('shown', 1),
#  ('figures', 1),
#  ('may', 1),
#  ('log', 1),
#  ('performa', 1),
#  ('prior', 1),
#  ('observed', 1),
#  ('allegation', 1),
#  ('varta', 1),
#  ('aa', 1),
#  ('alkaline', 1),
#  ('lines', 1),
#  ('run', 1),
#  ('vertically', 1),
#  ('horizontally', 1),
#  ('across', 1),
#  ('almost', 1),
#  ('impossible', 1),
#  ('much', 1),
#  ('completely', 1),
#  ('functional', 1),
#  ('attempts', 1),
#  ('clear', 1),
#  ('ineffective', 1),
#  ('potential', 1),
#  ('leak', 1),
#  ('sytem', 1),
#  ('though', 1),
#  ('stating', 1),
#  ('quite', 1),
#  ('currently', 1),
#  ('rdc', 1),
#  ('yesterday', 1),
#  ('stopped', 1),
#  ('solve', 1),
#  ('key', 1),
#  ('active', 1),
#  ('mishandled', 1),
#  ('visible', 1),
#  ('faults', 1),
#  ('chamber', 1),
#  ('intact', 1),
#  ('dry', 1),
#  ('keto', 1),
#  ('acidosis', 1),
#  ('standard', 1),
#  ('process', 1),
#  ('changing', 1),
#  ('insertion', 1),
#  ('consulted', 1),
#  ('hcp', 1),
#  ('lately', 1),
#  ('finding', 1),
#  ('walk', 1),
#  ('sit', 1),
#  ('breath', 1),
#  ('collapsed', 1),
#  ('pale', 1),
#  ('gasping', 1),
#  ('asystole', 1),
#  ('rhythm', 1),
#  ('cpr', 1),
#  ('commenced', 1),
#  ('scene', 1),
#  ('intubated', 1),
#  ('ed', 1),
#  ('asystolic', 1),
#  ('arrest', 1),
#  ('revived', 1),
#  ('dexcom', 1),
#  ('persistent', 1),
#  ('decided', 1),
#  ('attempt', 1),
#  ('removing', 1),
#  ('crack', 1),
#  ('distributor', 1),
#  ('hypoglycemia', 1),
#  ('overinfusion', 1),
#  ('disconencted', 1),
#  ('min', 1),
#  ('saw', 1),
#  ('unaccounted', 1),
#  ('manipulated', 1),
#  ('occasions', 1),
#  ('parent', 1),
#  ('unavailable', 1),
#  ('realized', 1),
#  ('alarmed', 1),
#  ('sort', 1),
#  ('neurological', 1),
#  ('brain', 1),
#  ('concerned', 1),
#  ('receipt', 1),
#  ('switching', 1),
#  ('eul', 1),
#  ('notifications', 1),
#  ('randomly', 1),
#  ('casing', 1),
#  ('repeatedly', 1),
#  ('rebooted', 1),
#  ('intermittent', 1),
#  ('rebooting', 1),
#  ('moderate', 1),
#  ('smelled', 1),
#  ('moisture', 1),
#  ('malfunctioning', 1),
#  ('enough', 1),
#  ('current', 1),
#  ('endocrinologist', 1),
#  ('seizure', 1),
#  ('therapy', 1),
#  ('measuring', 1),
#  ('associated', 1),
#  ('symptoms', 1),
#  ('lethargy', 1),
#  ('polydipsia', 1),
#  ('respiratory', 1),
#  ('review', 1),
#  ('safety', 1),
#  ('recorded', 1),
#  ('hyperglycemia', 1),
#  ('april', 1),
#  ('palpitations', 1),
#  ('light', 1),
#  ('headedness', 1),
#  ('dizziness', 1),
#  ('generally', 1),
#  ('rise', 1),
#  ('thrown', 1),
#  ('detaches', 1),
#  ('comfort', 1),
#  ('notices', 1),
#  ('connector', 1),
#  ('soft', 1),
#  ('product', 1),
#  ('bgls', 1),
#  ('idenitifed', 1)]
